# %% [markdown]
# # Converting processed database into sets

# %% [markdown]
# This notebook seeks to convert the prepared database into different sets of corresponding taxonomic level (species vs genus) and categories

# %%
options(repr.matrix.max.rows=20, repr.matrix.max.cols=200)
library(here)
library(tidyverse)
library(BiocSet)
here::i_am("analysis/db2set.ipynb");
source(here("R", "db_preprocess.R"));
# Out:
# here() starts at /dartfs-hpc/rc/home/k/f00345k/research/microbe_set_trait

# %%
db <- readRDS(file = here("output", "db_merged.rds"))
head(db)
# Out:
#   species_tax_id superkingdom phylum         class
# 1 1780362        Bacteria     Proteobacteria Epsilonproteobacteria
# 2 1848766        Bacteria     Proteobacteria Epsilonproteobacteria
# 3  654363        Bacteria     Proteobacteria Epsilonproteobacteria
# 4  247486        Bacteria     Proteobacteria Betaproteobacteria
# 5 1453587        Bacteria     Firmicutes     Bacilli
# 6 1159752        Bacteria     Firmicutes     Bacilli
#   order             family             genus         species
# 1 Campylobacterales Campylobacteraceae Campylobacter Campylobacter geochelonis
# 2 Campylobacterales Campylobacteraceae Campylobacter Campylobacter ornithocola
# 3 Campylobacterales Campylobacteraceae Campylobacter Campylobacter troglodytis
# 4 Burkholderiales   Comamonadaceae     Curvibacter   Curvibacter fontanus
# 5 Lactobacillales   Enterococcaceae    Enterococcus  Enterococcus crotali
# 6 Lactobacillales   Enterococcaceae    Enterococcus  Enterococcus lemanii
# ...

# %%
db <- as.data.table(db)

# %%
test <- "pathways"

# %%
db %>% filter(!test == "microaerophilic")
# Out:
#        species_tax_id superkingdom phylum         class
# 1      1780362        Bacteria     Proteobacteria Epsilonproteobacteria
# 2      1848766        Bacteria     Proteobacteria Epsilonproteobacteria
# 3       654363        Bacteria     Proteobacteria Epsilonproteobacteria
# 4       247486        Bacteria     Proteobacteria Betaproteobacteria
# 5      1453587        Bacteria     Firmicutes     Bacilli
# 6      1159752        Bacteria     Firmicutes     Bacilli
# 7      1805431        Bacteria     Firmicutes     Bacilli
# 8      1868794        Bacteria     Firmicutes     Bacilli
# 9      1868793        Bacteria     Firmicutes     Bacilli
# 10     1494461        Bacteria     Firmicutes     Bacilli
# ⋮      ⋮              ⋮            ⋮              ⋮
# 114251 NA             Bacteria     Proteobacteria Gammaproteobacteria
# 114252 NA             Bacteria     Actinobacteria Actinobacteria
# 114253 NA             Bacteria     Proteobacteria Gammaproteobacteria
# ...

# %%
databaes

# %%
db
# Out:
#        species_tax_id superkingdom phylum         class
# 1      1780362        Bacteria     Proteobacteria Epsilonproteobacteria
# 2      1848766        Bacteria     Proteobacteria Epsilonproteobacteria
# 3       654363        Bacteria     Proteobacteria Epsilonproteobacteria
# 4       247486        Bacteria     Proteobacteria Betaproteobacteria
# 5      1453587        Bacteria     Firmicutes     Bacilli
# 6      1159752        Bacteria     Firmicutes     Bacilli
# 7      1805431        Bacteria     Firmicutes     Bacilli
# 8      1868794        Bacteria     Firmicutes     Bacilli
# 9      1868793        Bacteria     Firmicutes     Bacilli
# 10     1494461        Bacteria     Firmicutes     Bacilli
# ⋮      ⋮              ⋮            ⋮              ⋮
# 114251 NA             Bacteria     Proteobacteria Gammaproteobacteria
# 114252 NA             Bacteria     Actinobacteria Actinobacteria
# 114253 NA             Bacteria     Proteobacteria Gammaproteobacteria
# ...
